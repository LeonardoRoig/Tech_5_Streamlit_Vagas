# %% [markdown]
# <a href="https://colab.research.google.com/github/LeonardoRoig/Tech_5_Streamlit_Vagas/blob/main/ETL_Modelo_Streamlit_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 ETL_Modelo_Streamlit_A
# Notebook que treina o modelo, gera ranking e prints do recrutador, e no final exporta os arquivos `.py` e `requirements.txt` para deploy no Streamlit Cloud.

# %% [markdown]
# ## 1) Imports e Configuração

# %%
import os, re, json
import pandas as pd, numpy as np
from typing import List, Optional
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, roc_auc_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

pd.set_option("display.max_colwidth", 300)

# Colunas padrão
ID_VAGA_COL, ID_CAND_COL, TARGET_COL = "id_vaga", "id_candidato", "target"

# Caminhos padrão
TRAIN_PATH, PENDING_PATH, EXPORT_DIR = "/content/aprovados_reprovados.csv", "/content/nao_classificados.csv", "/content/artifacts"
os.makedirs(EXPORT_DIR, exist_ok=True)

# %% [markdown]
# ## 2) Leitura dos Dados

# %%
df_train = pd.read_csv(TRAIN_PATH)
df_pending = pd.read_csv(PENDING_PATH)
print("Treino:", df_train.shape, "Pendentes:", df_pending.shape)
df_train.head()
# Out:
# Treino: (10110, 31) Pendentes: (34961, 31)
#    id_vaga         inf_titulo_vaga               inf_cliente inf_vaga_sap  \
# 0     5184  Consultor PP/QM Sênior  Morris, Moran and Dodson          Não
# 1     5184  Consultor PP/QM Sênior  Morris, Moran and Dodson          Não
# 2     5184  Consultor PP/QM Sênior  Morris, Moran and Dodson          Não
# 3     5184  Consultor PP/QM Sênior  Morris, Moran and Dodson          Não
# 4     5183   ANALISTA PL/JR C/ SQL  Morris, Moran and Dodson          Não
#
#      perfil_nivel_academico perfil_nivel profissional perfil_nivel_ingles  \
# 0  Ensino Superior Completo                    Sênior             Fluente
# 1  Ensino Superior Completo                    Sênior             Fluente
# 2  Ensino Superior Completo                    Sênior             Fluente
# 3  Ensino Superior Completo                    Sênior             Fluente
# 4  Ensino Superior Completo                  Analista              Nenhum
#
#   perfil_nivel_espanhol  \
# 0                Nenhum
# 1                Nenhum
# 2                Nenhum
# 3                Nenhum
# 4         Intermediário
#
#                                                                                                                                                                                                                                                                  perfil_competencia_tecnicas_e_comportamentais  \
# 0                                                                                     • Consultor PP/QM Sênior com experiencia em projetos de Rollout e implementação SAP ECC\n• Inglês mandatório\n• Remoto (Em alguns momentos / fases do projeto deverá estar presente na planta do cliente em Campinas/SP)
# 1                                                                                     • Consultor PP/QM Sênior com experiencia em projetos de Rollout e implementação SAP ECC\n• Inglês mandatório\n• Remoto (Em alguns momentos / fases do projeto deverá estar presente na planta do cliente em Campinas/SP)
# 2                                                                                     • Consultor PP/QM Sênior com experiencia em projetos de Rollout e implementação SAP ECC\n• Inglês mandatório\n• Remoto (Em alguns momentos / fases do projeto deverá estar presente na planta do cliente em Campinas/SP)
# 3                                                                                     • Consultor PP/QM Sênior com experiencia em projetos de Rollout e implementação SAP ECC\n• Inglês mandatório\n• Remoto (Em alguns momentos / fases do projeto deverá estar presente na planta do cliente em Campinas/SP)
# 4  Requisitos mandatórios:\n\no Conhecimentos Técnicos: Conhecimento SQL, e algum conhecimento de SAP SD\no Competências Interpessoais: Relacionamento interpessoal, foco no cliente, trabalho em equipe, excelente\ncomunicação, e adaptabilidade.\n\nRequisitos desejáveis:\no Idiomas: Espanhol nível in...
#
#                                                                                                                                                                                                                                                                                   perfil_principais_atividades  \
# 0                                                              Consultor PP/QM Sr.\n\n• Consultor PP/QM Sênior com experiencia em projetos de Rollout e implementação SAP ECC\n• Inglês mandatório\n• Remoto (Em alguns momentos / fases do projeto deverá estar presente na planta do cliente em Campinas/SP)
# 1                                                              Consultor PP/QM Sr.\n\n• Consultor PP/QM Sênior com experiencia em projetos de Rollout e implementação SAP ECC\n• Inglês mandatório\n• Remoto (Em alguns momentos / fases do projeto deverá estar presente na planta do cliente em Campinas/SP)
# 2                                                              Consultor PP/QM Sr.\n\n• Consultor PP/QM Sênior com experiencia em projetos de Rollout e implementação SAP ECC\n• Inglês mandatório\n• Remoto (Em alguns momentos / fases do projeto deverá estar presente na planta do cliente em Campinas/SP)
# 3                                                              Consultor PP/QM Sr.\n\n• Consultor PP/QM Sênior com experiencia em projetos de Rollout e implementação SAP ECC\n• Inglês mandatório\n• Remoto (Em alguns momentos / fases do projeto deverá estar presente na planta do cliente em Campinas/SP)
# 4  Descrição – Atividades:\n\no Monitoramento das interfaces KDP\no Monitoramento sistema B2B durante o dia\no Monitoramento do Whatsapp durante o dia\no Monitoramento da subida de pedidos (KDP, WAE e B2B)\no Suporte para equipe comercial quando tem problemas em algum cliente no WAE\no Suporte Apli...
#
#    ...  qualificacoes  certificacoes   experiencias         nivel_academico  \
# 0  ...  Não informado  Não informado  Não informado           Não informado
# 1  ...  Não informado  Não informado  Não informado           Não informado
# 2  ...  Não informado  Não informado  Não informado       Mestrado Completo
# 3  ...  Não informado  Não informado  Não informado           Não informado
# 4  ...  Não informado  Não informado  Não informado  Pós Graduação Cursando
#
#     nivel_ingles nivel_espanhol    cargo_atual nivel_profissional  \
# 0  Não informado  Não informado  Não informado      Não informado
# 1  Não informado  Não informado  Não informado      Não informado
# 2        Fluente        Fluente  Não informado      Não informado
# 3  Não informado  Não informado  Não informado      Não informado
# 4         Básico         Básico  Não informado      Não informado
#
#     outro_idioma                    cursos
# 0  Não informado             Não informado
# 1  Não informado             Não informado
# 2  Não informado  Engenharia da Computação
# 3  Não informado             Não informado
# 4  Não informado                   Direito
#
# [5 rows x 31 columns]

# %% [markdown]
# ## 3) Pré-processamento

# %%
X, y = df_train.drop(columns=[TARGET_COL]), df_train[TARGET_COL]
cat_cols = X.select_dtypes(include=["object"]).columns.tolist()
for c in [ID_VAGA_COL, ID_CAND_COL]:
    if c in cat_cols: cat_cols.remove(c)
preprocessor = ColumnTransformer([("cat", OneHotEncoder(handle_unknown="ignore"), cat_cols)], remainder="passthrough")

# %% [markdown]
# ## 4) Treino e Avaliação

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
model = Pipeline([("preprocess", preprocessor), ("clf", RandomForestClassifier(n_estimators=300, random_state=42))])
model.fit(X_train, y_train)
y_pred, y_proba = model.predict(X_val), model.predict_proba(X_val)[:,1]
print(classification_report(y_val, y_pred))
print("ROC AUC:", roc_auc_score(y_val, y_proba))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      1534
#          1.0       1.00      0.98      0.99       488
#
#     accuracy                           0.99      2022
#    macro avg       1.00      0.99      0.99      2022
# weighted avg       0.99      0.99      0.99      2022
#
# ROC AUC: 0.9998690875670592

# %% [markdown]
# A acurácia do modelo navalidação é de 99%.

# %% [markdown]
# ## 5) Predição e Ranking

# %%
df_pred = df_pending.copy()
df_pred["score"] = model.predict_proba(df_pred)[:,1]
df_pred["rank"] = df_pred.groupby(ID_VAGA_COL)["score"].rank(ascending=False, method="first")
ranking = df_pred[df_pred["rank"] <= 10].sort_values([ID_VAGA_COL,"rank"]).reset_index(drop=True)
pd.set_option('display.max_columns', None)
display(ranking.tail(200))
#display(ranking)
# Out:
#        id_vaga                                    inf_titulo_vaga  \
# 31565    14098             SAP S4HANA _L3 - SAP MM CGEMJP00282607
# 31566    14098             SAP S4HANA _L3 - SAP MM CGEMJP00282607
# 31567    14098             SAP S4HANA _L3 - SAP MM CGEMJP00282607
# 31568    14099  SAP S4HANA _L3 - SAP ABAP Sênior - CGEMJP00282590
# 31569    14099  SAP S4HANA _L3 - SAP ABAP Sênior - CGEMJP00282590
# ...        ...                                                ...
# 31760    14217                                             SAP SD
# 31761    14217                                             SAP SD
# 31762    14217                                             SAP SD
# 31763    14218                               Java Support Analyst
# 31764    14220   Consultor Sênior Especialista SAP LES-TRA - 1433
#
#                      inf_cliente inf_vaga_sap    perfil_nivel_academico  \
# 31565   Morris, Moran and Dodson          Sim  Ensino Superior Completo
# 31566   Morris, Moran and Dodson          Sim  Ensino Superior Completo
# 31567   Morris, Moran and Dodson          Sim  Ensino Superior Completo
# 31568   Morris, Moran and Dodson          Sim  Ensino Superior Completo
# 31569   Morris, Moran and Dodson          Sim  Ensino Superior Completo
# ...                          ...          ...                       ...
# 31760             Jenkins-Walker          Sim  Ensino Superior Completo
# 31761             Jenkins-Walker          Sim  Ensino Superior Completo
# 31762             Jenkins-Walker          Sim  Ensino Superior Completo
# 31763              Mann and Sons          Não  Ensino Superior Completo
# 31764  Glover, Warren and Norris          Sim  Ensino Superior Completo
#
#       perfil_nivel profissional perfil_nivel_ingles perfil_nivel_espanhol  \
# 31565                  Analista              Básico                   NaN
# 31566                  Analista              Básico                   NaN
# 31567                  Analista              Básico                   NaN
# 31568                    Sênior              Básico                   NaN
# 31569                    Sênior              Básico                   NaN
# ...                         ...                 ...                   ...
# 31760                    Sênior            Avançado         Intermediário
# 31761                    Sênior            Avançado         Intermediário
# 31762                    Sênior            Avançado         Intermediário
# 31763                  Analista             Fluente                   NaN
# 31764                    Sênior       Intermediário                   NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     perfil_competencia_tecnicas_e_comportamentais  \
# 31565                                                                                                                                                                                                             Descrição da Vaga:\n\n+ 5 anos de projetos SAP\nExperiencia em projetos de implementação S/4HANA\nConhecimento da metodologia Activate\nConhecimento comprovado de FIORI\nConhecimento comprovado em projeto de Retail S/4HANA\nConhecimento comprovado em: DADOS MESTRES RETAIL (ARTIGO, HIERARQUIA, GRUPO DE MERCADORIA, CENTRO, REFSITE); GESTÃO DE SORTIMENTO E CATALOGAÇÃO\nCLUSTERIZAÇÃO ; COMPRA COLETIVA; CROSS DOCKING ; FLOW THROUGH; ALOCAÇÃO DE MERCADORIA; REABASTECIMENTO DE CD E LOJA; RETAIL STORE OPERATION; ACORDOS COMERCIAIS (CONTRATOS) ; INTERAÇÃO COM PDV; PRECIFICAÇÃO DE VAREJO; NOÇÕES DE INTEGRAÇÃO COM PDV, PROMOÇÃO E VENDA CASADA
# 31566                                                                                                                                                                                                             Descrição da Vaga:\n\n+ 5 anos de projetos SAP\nExperiencia em projetos de implementação S/4HANA\nConhecimento da metodologia Activate\nConhecimento comprovado de FIORI\nConhecimento comprovado em projeto de Retail S/4HANA\nConhecimento comprovado em: DADOS MESTRES RETAIL (ARTIGO, HIERARQUIA, GRUPO DE MERCADORIA, CENTRO, REFSITE); GESTÃO DE SORTIMENTO E CATALOGAÇÃO\nCLUSTERIZAÇÃO ; COMPRA COLETIVA; CROSS DOCKING ; FLOW THROUGH; ALOCAÇÃO DE MERCADORIA; REABASTECIMENTO DE CD E LOJA; RETAIL STORE OPERATION; ACORDOS COMERCIAIS (CONTRATOS) ; INTERAÇÃO COM PDV; PRECIFICAÇÃO DE VAREJO; NOÇÕES DE INTEGRAÇÃO COM PDV, PROMOÇÃO E VENDA CASADA
# 31567                                                                                                                                                                                                             Descrição da Vaga:\n\n+ 5 anos de projetos SAP\nExperiencia em projetos de implementação S/4HANA\nConhecimento da metodologia Activate\nConhecimento comprovado de FIORI\nConhecimento comprovado em projeto de Retail S/4HANA\nConhecimento comprovado em: DADOS MESTRES RETAIL (ARTIGO, HIERARQUIA, GRUPO DE MERCADORIA, CENTRO, REFSITE); GESTÃO DE SORTIMENTO E CATALOGAÇÃO\nCLUSTERIZAÇÃO ; COMPRA COLETIVA; CROSS DOCKING ; FLOW THROUGH; ALOCAÇÃO DE MERCADORIA; REABASTECIMENTO DE CD E LOJA; RETAIL STORE OPERATION; ACORDOS COMERCIAIS (CONTRATOS) ; INTERAÇÃO COM PDV; PRECIFICAÇÃO DE VAREJO; NOÇÕES DE INTEGRAÇÃO COM PDV, PROMOÇÃO E VENDA CASADA
# 31568                                                                                                     Descrição da Vaga:\nApplication Consultant / SAP development / S4HANA / HANA / R4 Application consultants are supervised by a senior technical architect or similar manager and work to improve, create, and manage their online applications and computer software packages\n\nPelo menos cinco projetos comprovados em ECC;\nPelo menos três projetos comprovados em S/4 HANA;\nPelo menos um com SOLMAN e metodologia SAP Activate\nExperiência em Abode Forms, Workflow, SOAMANAGER, CDS View e Annotation\nConhecimento em Fiori, SEGW, OData Service, AMDP\n\nDesejável:\nMapeamento de campos SAP para Data warehouse/Data lake\nHANA Calculation View, SQL Script\n\nDiferencial:\nConhecimento Build (Apps, Process Automation)\nConhecimento em BTP\nHANA XSA
# 31569                                                                                                     Descrição da Vaga:\nApplication Consultant / SAP development / S4HANA / HANA / R4 Application consultants are supervised by a senior technical architect or similar manager and work to improve, create, and manage their online applications and computer software packages\n\nPelo menos cinco projetos comprovados em ECC;\nPelo menos três projetos comprovados em S/4 HANA;\nPelo menos um com SOLMAN e metodologia SAP Activate\nExperiência em Abode Forms, Workflow, SOAMANAGER, CDS View e Annotation\nConhecimento em Fiori, SEGW, OData Service, AMDP\n\nDesejável:\nMapeamento de campos SAP para Data warehouse/Data lake\nHANA Calculation View, SQL Script\n\nDiferencial:\nConhecimento Build (Apps, Process Automation)\nConhecimento em BTP\nHANA XSA
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# 31760  Experiência na implementação de projetos de SD, participando desde a análise de requisitos e\nlevantamento de dados até o suporte pós implementação;\n• Atendimento de demandas relacionadas a SD de diversos processos de venda, como\nconsignação, retorno, devolução, third-party, nota de crédito/débito, sucata, demonstração, etc;\n• Experiência em localização Brasil;\n• Experiência com Nota Fiscal Eletrônica;\n• Realização de configurações para atender demandas de diferentes processos de vendas, desde\na criação do documento de venda, da remessa e todo o fluxo até a fatura e a nota fiscal;\n• Criação de soluções customizadas junto aos clientes;\n• Elaboração de cenários de testes;\n• Experiência na integração de sistemas legados com o SAP SD (ECC/S4Hana);\n• Experiência em carga de dados no sistema – Master Data e Dados Transacionais
# 31761  Experiência na implementação de projetos de SD, participando desde a análise de requisitos e\nlevantamento de dados até o suporte pós implementação;\n• Atendimento de demandas relacionadas a SD de diversos processos de venda, como\nconsignação, retorno, devolução, third-party, nota de crédito/débito, sucata, demonstração, etc;\n• Experiência em localização Brasil;\n• Experiência com Nota Fiscal Eletrônica;\n• Realização de configurações para atender demandas de diferentes processos de vendas, desde\na criação do documento de venda, da remessa e todo o fluxo até a fatura e a nota fiscal;\n• Criação de soluções customizadas junto aos clientes;\n• Elaboração de cenários de testes;\n• Experiência na integração de sistemas legados com o SAP SD (ECC/S4Hana);\n• Experiência em carga de dados no sistema – Master Data e Dados Transacionais
# 31762  Experiência na implementação de projetos de SD, participando desde a análise de requisitos e\nlevantamento de dados até o suporte pós implementação;\n• Atendimento de demandas relacionadas a SD de diversos processos de venda, como\nconsignação, retorno, devolução, third-party, nota de crédito/débito, sucata, demonstração, etc;\n• Experiência em localização Brasil;\n• Experiência com Nota Fiscal Eletrônica;\n• Realização de configurações para atender demandas de diferentes processos de vendas, desde\na criação do documento de venda, da remessa e todo o fluxo até a fatura e a nota fiscal;\n• Criação de soluções customizadas junto aos clientes;\n• Elaboração de cenários de testes;\n• Experiência na integração de sistemas legados com o SAP SD (ECC/S4Hana);\n• Experiência em carga de dados no sistema – Master Data e Dados Transacionais
# 31763                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   • Horário de trabalho: Domingo a quinta -feira: 13 às 22h.\n• Candidatos preferencialmente devem estar em Londrina (presencial)/ São Paulo.\n\n• Inglês avançado/fluente.
# 31764                                    Conhecimentos Técnicos Requeridos\nConsultor SAP especializado em SAP LES (Logistics Execution System), com experiência na implementação, suporte e otimização dos módulos SD, LE-TRA. Forte conhecimento em gestão de fretes, roteirização, cálculo de tarifas e integração com transportadoras. Habilidade para analisar processos logísticos, propor melhorias e garantir conformidade com as regulamentações fiscais.\n\nCOMPETÊNCIAS PRINCIPAIS\nImplementação e suporte dos módulos SD, TM e LE-TRA\nGestão e cálculo de fretes, auditoria e liquidação de transportadoras\nIntegração do SAP LES com módulos MM, SD, FI e EWM\nConhecimento em CT-e, NF-e, regras fiscais e tributárias\nOtimização de processos logísticos e roteirização de transporte\nConhecimento em ABAP (debugging) para análise de erros e customizações;
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                perfil_principais_atividades  \
# 31565                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Vaga: SAP S4HANA _L3 - SAP MM CGEMJP00282607 – 4 POSIÇÕES\nPeríodo de Alocação: 03/02/2025 até 01/08/2025 - Alocação\nAtuação: Híbrida\n\nDisponibilidade para Viagens: Não se aplica\n\nIdiomas: não se aplica
# 31566                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Vaga: SAP S4HANA _L3 - SAP MM CGEMJP00282607 – 4 POSIÇÕES\nPeríodo de Alocação: 03/02/2025 até 01/08/2025 - Alocação\nAtuação: Híbrida\n\nDisponibilidade para Viagens: Não se aplica\n\nIdiomas: não se aplica
# 31567                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Vaga: SAP S4HANA _L3 - SAP MM CGEMJP00282607 – 4 POSIÇÕES\nPeríodo de Alocação: 03/02/2025 até 01/08/2025 - Alocação\nAtuação: Híbrida\n\nDisponibilidade para Viagens: Não se aplica\n\nIdiomas: não se aplica
# 31568                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Vaga: SAP S4HANA _L3 - SAP ABAP SR CGEMJP00282590 - 10 POSIÇÕES\nPeríodo de Alocação: 03/02/2025 até 01/08/2025 - Alocação\nAtuação: Híbrida\n\nDisponibilidade para Viagens: Não se aplica\n\nIdiomas: não se aplica
# 31569                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Vaga: SAP S4HANA _L3 - SAP ABAP SR CGEMJP00282590 - 10 POSIÇÕES\nPeríodo de Alocação: 03/02/2025 até 01/08/2025 - Alocação\nAtuação: Híbrida\n\nDisponibilidade para Viagens: Não se aplica\n\nIdiomas: não se aplica
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# 31760                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Experiência na implementação de projetos de SD, participando desde a análise de requisitos e\nlevantamento de dados até o suporte pós implementação;\n• Atendimento de demandas relacionadas a SD de diversos processos de venda, como\nconsignação, retorno, devolução, third-party, nota de crédito/débito, sucata, demonstração, etc;\n• Experiência em localização Brasil;\n• Experiência com Nota Fiscal Eletrônica;\n• Realização de configurações para atender demandas de diferentes processos de vendas, desde\na criação do documento de venda, da remessa e todo o fluxo até a fatura e a nota fiscal;\n• Criação de soluções customizadas junto aos clientes;\n• Elaboração de cenários de testes;\n• Experiência na integração de sistemas legados com o SAP SD (ECC/S4Hana);\n• Experiência em carga de dados no sistema – Master Data e Dados Transacionais
# 31761                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Experiência na implementação de projetos de SD, participando desde a análise de requisitos e\nlevantamento de dados até o suporte pós implementação;\n• Atendimento de demandas relacionadas a SD de diversos processos de venda, como\nconsignação, retorno, devolução, third-party, nota de crédito/débito, sucata, demonstração, etc;\n• Experiência em localização Brasil;\n• Experiência com Nota Fiscal Eletrônica;\n• Realização de configurações para atender demandas de diferentes processos de vendas, desde\na criação do documento de venda, da remessa e todo o fluxo até a fatura e a nota fiscal;\n• Criação de soluções customizadas junto aos clientes;\n• Elaboração de cenários de testes;\n• Experiência na integração de sistemas legados com o SAP SD (ECC/S4Hana);\n• Experiência em carga de dados no sistema – Master Data e Dados Transacionais
# 31762                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Experiência na implementação de projetos de SD, participando desde a análise de requisitos e\nlevantamento de dados até o suporte pós implementação;\n• Atendimento de demandas relacionadas a SD de diversos processos de venda, como\nconsignação, retorno, devolução, third-party, nota de crédito/débito, sucata, demonstração, etc;\n• Experiência em localização Brasil;\n• Experiência com Nota Fiscal Eletrônica;\n• Realização de configurações para atender demandas de diferentes processos de vendas, desde\na criação do documento de venda, da remessa e todo o fluxo até a fatura e a nota fiscal;\n• Criação de soluções customizadas junto aos clientes;\n• Elaboração de cenários de testes;\n• Experiência na integração de sistemas legados com o SAP SD (ECC/S4Hana);\n• Experiência em carga de dados no sistema – Master Data e Dados Transacionais
# 31763  **Job Description: Support Analyst (Unix, SQL, Java L2 Production Support)**\n\n**Role Overview:**\nWe are seeking a skilled and motivated Support Analyst with experience in Unix, SQL, and Java to join our L2 Production Support team. The ideal candidate will provide technical support, troubleshoot complex issues, and ensure the stability and efficiency of production systems. This role involves working closely with development teams, operations, and stakeholders to drive quick resolution of incidents and proactive problem management.\n\n---\n\n**Key Responsibilities:**\n1. **Unix Troubleshooting and Support:**\n- Monitor and troubleshoot applications in Unix environments.\n- Analyze logs to identify and resolve underlying issues.\n- Perform tasks using Unix commands such as `sed`, `awk`, `grep`, `cut`, `tail`, `ps`, `kill`, and others.\n- Manage system performance through capacity management and log segmentation.\n\n2. **Database Management:**\n- Work with RDBMS environments like Sybase ASE/IQ, Oracle, or DB2.\n- Diagnose and resolve database issues, including deadlocks and performance tuning.\n- Write and debug advanced SQL queries, stored procedures, and indexes.\n\n3. **Programming and Scripting:**\n- Utilize structured or object-oriented programming languages (Java, C++, VB, .NET, etc.).\n- Leverage scripting languages like Shell, Perl, Python, or JavaScript for automation and problem-solving.\n- Develop scripts for file parsing, process automation, and log analysis.\n\n4. **Incident and Problem Management:**\n- Handle production incidents, identify patterns, and analyze root causes.\n- Collaborate with App Dev teams to implement effective solutions and process improvements.\n- Manage incidents, problems, and changes within ITIL frameworks.\n\n5. **Team Collaboration and Leadership:**\n- Provide technical guidance to support specialists and junior team members.\n- Facilitate clear communication with stakeholders regarding technical and functional issues.\n- Lead discussions with App Dev and senior stakeholders to drive resolution strategies.\n\n6. **Continuous Improvement:**\n- Observe system performance to suggest and implement proactive optimizations.\n- Stay updated with emerging technologies and best practices in support and development.\n\n---\n\n**Skills and Qualifications:**\n- **Technical Expertise:** Proficiency in Unix environments, advanced SQL queries, and at least one programming language (Java preferred).\n- **Problem-Solving Skills:** Strong analytical skills for identifying root causes and resolving issues in development or production settings.\n- **Communication Skills:** Excellent ability to articulate technical details and coordinate with cross-functional teams.\n- **Experience:** Proven track record in application process management and production support, with hands-on knowledge of incident, problem, and change management processes.\n\n---\n\n**Preferred Qualifications:**\n- Certification in ITIL or relevant frameworks.\n- Exposure to monitoring tools and performance tuning techniques.\n- Experience working in fast-paced, high-pressure production environments.\n\nJoin us to make a meaningful impact on system reliability and performance while growing your career in a dynamic, collaborative environment.
# 31764                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Vaga: CONSULTOR SENIOR ESPECIALISTA SAP LES-TRA\nModelo de trabalho: Presencial\nLocal da Vaga (Cidade) 1 vaga para São Paulo (Faria Lima)\nLocal da Vaga (Cidade) 1 vaga para Suzano ( Rua Prudente de Moraes)\nLocal da Vaga (Estado): SP\nInício: Imediato\nPrazo: 12 Meses\nIdioma: Português / Inglês intermediário\nDespesas: Reembolsáveis
#
#                                                   titulo  id_candidato  \
# 31565             SAP S4HANA _L3 - SAP MM CGEMJP00282607         20896
# 31566             SAP S4HANA _L3 - SAP MM CGEMJP00282607            15
# 31567             SAP S4HANA _L3 - SAP MM CGEMJP00282607          8320
# 31568  SAP S4HANA _L3 - SAP ABAP Sênior - CGEMJP00282590         12386
# 31569  SAP S4HANA _L3 - SAP ABAP Sênior - CGEMJP00282590         15143
# ...                                                  ...           ...
# 31760                                             SAP SD         10720
# 31761                                             SAP SD         13635
# 31762                                             SAP SD         47044
# 31763                               Java Support Analyst         40384
# 31764   Consultor Sênior Especialista SAP LES-TRA - 1433         15042
#
#                         nome data_candidatura        recrutador  \
# 31565           Maria da Luz       30-01-2025       Elisa Nunes
# 31566      Dr. Erick da Rosa       29-01-2025       Elisa Nunes
# 31567         Augusto Vieira       30-01-2025       Elisa Nunes
# 31568      Danilo Nascimento       29-01-2025    Yasmin da Rosa
# 31569            Lara Santos       11-02-2025    Yasmin da Rosa
# ...                      ...              ...               ...
# 31760           Luigi Novaes       26-02-2025    Yasmin da Rosa
# 31761            Kevin Porto       26-02-2025    Yasmin da Rosa
# 31762        Isabelly Vieira       26-02-2025  Emanuelly Vieira
# 31763   Dr. Vitor Hugo Silva       26-02-2025     Laura Pacheco
# 31764  Pedro Lucas das Neves       28-02-2025       Elisa Nunes
#
#                 situacao_candidado  target objetivo_profissional  \
# 31565  Encaminhado ao Requisitante     NaN         Não informado
# 31566  Encaminhado ao Requisitante     NaN             Consultor
# 31567                     Prospect     NaN         Consultor SAP
# 31568  Encaminhado ao Requisitante     NaN                  ABAP
# 31569  Encaminhado ao Requisitante     NaN    Consultor ABAP SR.
# ...                            ...     ...                   ...
# 31760  Encaminhado ao Requisitante     NaN  CONSULTOR SAP SD LES
# 31761                     Prospect     NaN          consultor SD
# 31762                     Prospect     NaN      Consultor SAP SD
# 31763           Entrevista Técnica     NaN                 Linux
# 31764  Encaminhado ao Requisitante     NaN         Não informado
#
#         titulo_profissional   area_atuacao conhecimentos_tecnicos  \
# 31565         Não informado  Não informado          Não informado
# 31566             Consultor  Não informado          Não informado
# 31567         Consultor SAP  Não informado          Não informado
# 31568                  ABAP  Não informado          Não informado
# 31569    Consultor ABAP SR.  Não informado               SAP ABAP
# ...                     ...            ...                    ...
# 31760  CONSULTOR SAP SD LES  Não informado          Não informado
# 31761          consultor SD  Não informado          Não informado
# 31762      Consultor SAP SD  Não informado          Não informado
# 31763                 Linux  Não informado          Não informado
# 31764         Não informado  Não informado          Não informado
#
#        qualificacoes  certificacoes   experiencias           nivel_academico  \
# 31565  Não informado  Não informado  Não informado             Não informado
# 31566  Não informado  Não informado  Não informado    Pós Graduação Completo
# 31567  Não informado  Não informado  Não informado             Não informado
# 31568  Não informado  Não informado  Não informado             Não informado
# 31569  Não informado  Não informado  Não informado  Ensino Superior Completo
# ...              ...            ...            ...                       ...
# 31760  Não informado  Não informado  Não informado             Não informado
# 31761  Não informado  Não informado  Não informado             Não informado
# 31762  Não informado  Não informado  Não informado             Não informado
# 31763  Não informado  Não informado  Não informado             Não informado
# 31764  Não informado  Não informado  Não informado             Não informado
#
#         nivel_ingles nivel_espanhol    cargo_atual nivel_profissional  \
# 31565  Intermediário  Não informado  Não informado      Não informado
# 31566  Não informado  Não informado  Não informado      Não informado
# 31567  Não informado  Não informado  Não informado      Não informado
# 31568  Não informado  Não informado  Não informado      Não informado
# 31569  Intermediário         Básico  Não informado      Não informado
# ...              ...            ...            ...                ...
# 31760  Não informado  Não informado  Não informado      Não informado
# 31761  Não informado  Não informado  Não informado      Não informado
# 31762  Não informado  Não informado  Não informado      Não informado
# 31763  Não informado  Não informado  Não informado      Não informado
# 31764  Não informado  Não informado  Não informado      Não informado
#
#         outro_idioma                    cursos     score  rank
# 31565  Não informado             Não informado  0.126667   4.0
# 31566  Não informado                       MBA  0.120000   5.0
# 31567  Não informado             Não informado  0.103333   6.0
# 31568  Não informado             Não informado  0.180000   1.0
# 31569  Não informado  Matemática computacional  0.173333   2.0
# ...              ...                       ...       ...   ...
# 31760  Não informado             Não informado  0.143333   8.0
# 31761  Não informado             Não informado  0.140000   9.0
# 31762  Não informado             Não informado  0.136667  10.0
# 31763  Não informado             Não informado  0.103333   1.0
# 31764  Não informado             Não informado  0.123333   1.0
#
# [200 rows x 33 columns]

# %% [markdown]
# ## 6) Funções auxiliares para Similaridade e Print do Recrutador

# %%
def top_terms_overlap(job_text, cand_text, k=8):
    tok = lambda s: set(re.findall(r"[\w\-\+]+", str(s).lower()))
    jset, cset = tok(job_text), tok(cand_text)
    return {"match_terms": list(jset & cset)[:k], "missing_terms": list(jset - cset)[:k]}

def local_similarity(job_text, cand_text):
    vec = TfidfVectorizer(max_features=2000)
    tfidf = vec.fit_transform([str(job_text), str(cand_text)])
    return float(cosine_similarity(tfidf[0], tfidf[1])[0][0])

# %% [markdown]
# ## 7) Exportar `train_and_rank.py`

# %%
train_code = """
import re, json
import pandas as pd, numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

ID_VAGA_COL, ID_CAND_COL, TARGET_COL = "id_vaga", "id_candidato", "target"

def top_terms_overlap(job_text, cand_text, k=8):
    tok = lambda s: set(re.findall(r"[\w\-\+]+", str(s).lower()))
    jset, cset = tok(job_text), tok(cand_text)
    return {"match_terms": list(jset & cset)[:k], "missing_terms": list(jset - cset)[:k]}

def local_similarity(job_text, cand_text):
    vec = TfidfVectorizer(max_features=2000)
    tfidf = vec.fit_transform([str(job_text), str(cand_text)])
    return float(cosine_similarity(tfidf[0], tfidf[1])[0][0])

def run_pipeline(train_path, pending_path, export_dir="/content/artifacts", top_k=10):
    df_train, df_pending = pd.read_csv(train_path), pd.read_csv(pending_path)
    X, y = df_train.drop(columns=[TARGET_COL]), df_train[TARGET_COL]
    cat_cols = X.select_dtypes(include=["object"]).columns.tolist()
    for c in [ID_VAGA_COL, ID_CAND_COL]:
        if c in cat_cols: cat_cols.remove(c)
    preprocessor = ColumnTransformer([("cat", OneHotEncoder(handle_unknown="ignore"), cat_cols)], remainder="passthrough")
    pipe = Pipeline([("preprocess", preprocessor), ("clf", RandomForestClassifier(n_estimators=300, random_state=42))])
    pipe.fit(X, y)
    df_pred = df_pending.copy()
    df_pred["score"] = pipe.predict_proba(df_pred)[:,1]
    df_pred["rank"] = df_pred.groupby(ID_VAGA_COL)["score"].rank(ascending=False, method="first")
    ranking = df_pred[df_pred["rank"] <= top_k].sort_values([ID_VAGA_COL,"rank"]).reset_index(drop=True)
    ranking.to_csv(f"{export_dir}/ranking_por_vaga.csv", index=False)
    cards = ranking[[ID_VAGA_COL, ID_CAND_COL, "score", "rank"]].to_dict(orient="records")
    with open(f"{export_dir}/cards_recrutador.json", "w", encoding="utf-8") as f:
        json.dump(cards, f, ensure_ascii=False, indent=2)
    return ranking
"""

with open(os.path.join(EXPORT_DIR, "train_and_rank.py"), "w", encoding="utf-8") as f:
    f.write(train_code)
print("Arquivo train_and_rank.py exportado!")
# Out:
# Arquivo train_and_rank.py exportado!
# <>:14: SyntaxWarning: invalid escape sequence '\w'
# <>:14: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipython-input-2677638376.py:14: SyntaxWarning: invalid escape sequence '\w'
#   tok = lambda s: set(re.findall(r"[\w\-\+]+", str(s).lower()))

# %% [markdown]
# ## 8) Exportar `app.py`

# %%
app_code = """
import json, pandas as pd, streamlit as st
from train_and_rank import run_pipeline

st.set_page_config(page_title="Netflix das Vagas", layout="wide")
st.title("🎬 Netflix das Vagas — Top 10 Candidatos por Vaga")

train_file = st.file_uploader("CSV de treino (aprovados/reprovados)", type=["csv"])
pending_file = st.file_uploader("CSV de pendentes (não classificados)", type=["csv"])

if train_file and pending_file:
    with open("train.csv","wb") as f: f.write(train_file.getbuffer())
    with open("pending.csv","wb") as f: f.write(pending_file.getbuffer())
    ranking = run_pipeline("train.csv", "pending.csv", export_dir=".")
    st.success("Pipeline executado!")

    vagas = sorted(ranking["id_vaga"].unique().tolist())
    vaga_sel = st.sidebar.selectbox("Selecione a vaga", vagas)
    top = ranking[ranking["id_vaga"]==vaga_sel].sort_values("rank")
    st.subheader(f"Top {len(top)} candidatos para a vaga {vaga_sel}")

    cols = st.columns(5)
    for i, (_, row) in enumerate(top.iterrows()):
        col = cols[i % 5]
        with col:
            st.markdown(f"### 👤 Candidato {row['id_candidato']}")
            st.metric("Score (modelo)", f"{row['score']:.3f}")
            st.caption(f"Rank: {row['rank']}")
    with st.expander("Tabela completa da vaga"):
        st.dataframe(top)
else:
    st.info("Faça upload dos dois arquivos CSV para rodar o pipeline.")
"""

with open(os.path.join(EXPORT_DIR, "app.py"), "w", encoding="utf-8") as f:
    f.write(app_code)
print("Arquivo app.py exportado!")
# Out:
# Arquivo app.py exportado!

# %% [markdown]
# ## 9) Exportar `requirements.txt`

# %%
reqs = """pandas==2.2.2
numpy==1.26.4
scikit-learn==1.4.2
streamlit==1.32.0
"""

with open(os.path.join(EXPORT_DIR, "requirements.txt"), "w", encoding="utf-8") as f:
    f.write(reqs)
print("Arquivo requirements.txt exportado!")
# Out:
# Arquivo requirements.txt exportado!
